# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Kkma
import konlpy
from PIL import Image
import numpy as np

# %%
# 데이터 불러오기
with open("./food_blog_text.txt", 'r', encoding='UTF-8') as f:
    text=f.read()

# %%
#text

# %%
# 형태소 분석기로 전처리

okt=Okt()

sentences_tag=[]
sentences_tag=okt.pos(text) 

noun_adj_list=[]

# %%
# 명사, 형용사 추출

for word, tag in sentences_tag:
    if tag in ['Noun' , 'Adjective']: 
        noun_adj_list.append(word)

# %%
# 최빈 출연 단어 100개 저장

counts=Counter(noun_adj_list)
tags=counts.most_common(100)

# %%
# 워드 클라우드 시각화

img=Image.open('./heart.png')
img_array=np.array(img)

wc=WordCloud(font_path='malgun', width=800, height=800, scale=2.0, max_font_size=100, background_color='white', max_words=100, mask=img_array)
gen=wc.generate_from_frequencies(c)
plt.figure()
plt.axis('off') 
plt.imshow(gen,interpolation="bilinear")
